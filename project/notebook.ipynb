# %% [markdown]
# # Agentic Recruitment Assistant Demo
#
# Quick notebook to run the LangGraph recruitment assistant locally.

# %%
from matching_agent import RecruitmentAssistant

agent = RecruitmentAssistant()
agent.bootstrap_index(force_reindex=False)

# %%
report = agent.run('Find Python developers with 5+ years experience and AWS exposure')
report
